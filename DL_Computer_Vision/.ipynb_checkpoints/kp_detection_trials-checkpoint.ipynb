# %%
from tensorflow.keras import layers
from tensorflow import keras
import tensorflow as tf
from tensorflow.keras.applications.resnet50 import ResNet50

# %%
# from imgaug.augmentables.kps import KeypointsOnImage
# from imgaug.augmentables.kps import Keypoint
# import imgaug.augmenters as iaa

from PIL import Image
import cv2
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt
import pandas as pd
import numpy as np
import json
import os

# %%
IMG_HEIGHT = 480
IMG_WIDTH = 640
BATCH_SIZE = 64
EPOCHS = 10
NUM_KEYPOINTS = 7 * 2  # 24 pairs each having x and y coordinates

# %%
IMG_DIR = "depth_dataset_2D"
JSON = "result.json"
KEYPOINT_DEF = (
    "https://github.com/benjiebob/StanfordExtra/raw/master/keypoint_definitions.csv"
)

# Load the ground-truth annotations.
with open(JSON) as infile:
    json_data = json.load(infile)

# Set up a dictionary, mapping all the ground-truth information
# with respect to the path of the image.
json_dict = {i["image"]: i for i in json_data}

# %%
print(json_dict)
# Out:
# {'61.jpg': {'id': 61, 'image': '61.jpg', 'keypoints': [[198, 462], [194, 328], [293, 243], [317, 261], [447, 361], [477, 340], [505, 384]]}, '1168.jpg': {'id': 1168, 'image': '1168.jpg', 'keypoints': [[200, 462], [191, 323], [56, 317], [65, 285], [195, 194], [188, 157], [229, 146]]}, '1308.jpg': {'id': 1308, 'image': '1308.jpg', 'keypoints': [[198, 462], [192, 324], [56, 317], [65, 286], [204, 213], [204, 176], [247, 172]]}, '792.jpg': {'id': 792, 'image': '792.jpg', 'keypoints': [[198, 462], [197, 322], [105, 224], [133, 201], [293, 236], [312, 204], [352, 229]]}, '1301.jpg': {'id': 1301, 'image': '1301.jpg', 'keypoints': [[198, 462], [192, 324], [56, 317], [66, 286], [204, 211], [203, 176], [247, 172]]}, '1039.jpg': {'id': 1039, 'image': '1039.jpg', 'keypoints': [[199.0, 463.0], [194.0, 324.0], [63.0, 286.0], [76.0, 258.0], [226.0, 201.0], [228.0, 161.0], [272.0, 161.0]]}, '24.jpg': {'id': 24, 'image': '24.jpg', 'keypoints': [[198, 462], [194, 328], [293, 241], [315, 261], [447, 36
# ...

# %%
# Utility for reading an image and for getting its annotations.
def get_img_kp(name):
    data = json_dict[name]
#     print(data)
    img_data = plt.imread(os.path.join(IMG_DIR, data["image"]))
#     print(img_data)
#     # If the image is RGBA convert it to RGB.
#     if img_data.shape[-1] == 4:
#         img_data = img_data.astype(np.uint8)
#         img_data = Image.fromarray(img_data)
#         img_data = np.array(img_data.convert("RGB"))
    data["img_data"] = img_data
#     print(data["img_data"])

    return data

# %%
get_img_kp("61.jpg")
# Out:
# {'id': 61,
#  'image': '61.jpg',
#  'keypoints': [[198, 462],
#   [194, 328],
#   [293, 243],
#   [317, 261],
#   [447, 361],
#   [477, 340],
#   [505, 384]],
#  'img_data': array([[9, 9, 9, ..., 8, 8, 9],
#         [9, 9, 9, ..., 8, 9, 9],
#         [9, 9, 9, ..., 9, 9, 9],
#         ...,
#         [9, 9, 9, ..., 9, 9, 9],
#         [9, 9, 9, ..., 9, 9, 9],
#         [9, 9, 9, ..., 9, 9, 9]], dtype=uint8)}

# %%
# Parts of this code come from here:
# https://github.com/benjiebob/StanfordExtra/blob/master/demo.ipynb
def visualize_keypoints(images, keypoints):
    fig, axes = plt.subplots(nrows=len(images), ncols=2, figsize=(32, 32))
#     print(axes)
    [ax.axis("off") for ax in np.ravel(axes)]

    for (ax_orig, ax_all), image, current_keypoint in zip(axes, images, keypoints):
        ax_orig.imshow(image)
        ax_all.imshow(image)

        # If the keypoints were formed by `imgaug` then the coordinates need
        # to be iterated differently.
#         if isinstance(current_keypoint, KeypointsOnImage):
#             for idx, kp in enumerate(current_keypoint.keypoints):
#                 ax_all.scatter(
#                     [kp.x], [kp.y], c=colours[idx], marker="x", s=50, linewidths=5
#                 )
#         else:
        current_keypoint = np.array(current_keypoint)
        # Since the last entry is the visibility flag, we discard it.
#         current_keypoint = current_keypoint
        for idx, (x, y) in enumerate(current_keypoint):
            ax_all.scatter([x], [y], marker="x", s=50, linewidths=5)

    plt.tight_layout(pad=2.0)
    plt.show()

# %%
# Select four samples randomly for visualization.
print(type(json_dict.keys()))
print(json_dict.keys())

samples = list((json_dict.keys()))
num_samples = 4
selected_samples = np.random.choice(samples, num_samples, replace=False)

images, keypoints = [], []

for sample in selected_samples:
    data = get_img_kp(sample)
    image = data["img_data"]
#     print(image)
#     image = cv2.imread("depth_dataset_2D/"+str(image))
    keypoint = data["keypoints"]

    images.append(image)
    keypoints.append(keypoint)

# print(images)

visualize_keypoints(images, keypoints)
# Out:
# <class 'dict_keys'>
# ...

# %%
class KeyPointsDataset(keras.utils.Sequence):
    def __init__(self, image_keys, batch_size=BATCH_SIZE, train=True):
        self.image_keys = image_keys
#         self.aug = aug
        self.batch_size = batch_size
        self.train = train
        self.on_epoch_end()

    def __len__(self):
        return len(self.image_keys) // self.batch_size

    def on_epoch_end(self):
        self.indexes = np.arange(len(self.image_keys))
        if self.train:
            np.random.shuffle(self.indexes)

    def __getitem__(self, index):
        indexes = self.indexes[index * self.batch_size : (index + 1) * self.batch_size]
        image_keys_temp = [self.image_keys[k] for k in indexes]
        (images, keypoints) = self.__data_generation(image_keys_temp)

        return (images, keypoints)

    def __data_generation(self, image_keys_temp):
        batch_images = np.empty((self.batch_size, IMG_HEIGHT, IMG_WIDTH, 3), dtype="int")
        batch_keypoints = np.empty(
            (self.batch_size, 1, 1, NUM_KEYPOINTS), dtype="float32"
        )

        for i, key in enumerate(image_keys_temp):
            data = get_img_kp(key)
            current_keypoint = np.array(data["keypoints"])[:, :2]
            kps = []

            # To apply our data augmentation pipeline, we first need to
            # form Keypoint objects with the original coordinates.
#             for j in range(0, len(current_keypoint)):
#                 kps.append(Keypoint(x=current_keypoint[j][0], y=current_keypoint[j][1]))

            # We then project the original image and its keypoint coordinates.
            current_image = data["img_data"]
#             kps_obj = KeypointsOnImage(kps, shape=current_image.shape)

            # Apply the augmentation pipeline.
#             (new_image, new_kps_obj) = self.aug(image=current_image, keypoints=kps_obj)
#             batch_images[i,] = new_image

            # Parse the coordinates from the new keypoint object.
#             kp_temp = []
#             for keypoint in new_kps_obj:
#                 kp_temp.append(np.nan_to_num(keypoint.x))
#                 kp_temp.append(np.nan_to_num(keypoint.y))

            # More on why this reshaping later.
            batch_keypoints[i,] = np.array(current_keypoint).reshape(1, 1, 7 * 2)

        # Scale the coordinates to [0, 1] range.
        batch_keypoints = batch_keypoints / (IMG_HEIGHT*IMG_WIDTH)

        return (batch_images, batch_keypoints)

# %%
np.random.shuffle(samples)
train_keys, validation_keys = (
    samples[int(len(samples) * 0.15) :],
    samples[: int(len(samples) * 0.15)],
)

# %%
train_dataset = KeyPointsDataset(train_keys)
validation_dataset = KeyPointsDataset(validation_keys, train=False)

print(f"Total batches in training set: {len(train_dataset)}")
print(f"Total batches in validation set: {len(validation_dataset)}")

sample_images, sample_keypoints = next(iter(train_dataset))
# assert sample_keypoints.max() == 1.0
# assert sample_keypoints.min() == 0.0

sample_keypoints = sample_keypoints[:4].reshape(-1, 7, 2) * IMG_HEIGHT * IMG_WIDTH
visualize_keypoints(sample_images[:4], sample_keypoints)
# Out:
# Total batches in training set: 20
# Total batches in validation set: 3

# %%
def get_model():
    # Load the pre-trained weights of MobileNetV2 and freeze the weights
    backbone = ResNet50(
        weights="imagenet", include_top=False, input_shape=(IMG_HEIGHT, IMG_WIDTH, 3)
    )
    backbone.trainable = False

    inputs = layers.Input((IMG_HEIGHT, IMG_WIDTH, 3))
    x = keras.applications.resnet50.preprocess_input(inputs)
    x = backbone(x)
    x = layers.Dropout(0.3)(x)
    x = layers.SeparableConv2D(
        NUM_KEYPOINTS, kernel_size=5, strides=1, activation="relu"
    )(x)
    outputs = layers.SeparableConv2D(
        NUM_KEYPOINTS, kernel_size=3, strides=1, activation="relu"
    )(x)

    return keras.Model(inputs, outputs, name="keypoint_detector")

# %%
get_model().summary()
# Out:
# Model: "keypoint_detector"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_62 (InputLayer)       [(None, 480, 640, 3)]     0
#
#  tf.__operators__.getitem_12  (None, 480, 640, 3)      0
#   (SlicingOpLambda)
#
#  tf.nn.bias_add_12 (TFOpLamb  (None, 480, 640, 3)      0
#  da)
#
#  resnet50 (Functional)       (None, 15, 20, 2048)      23587712
#
#  dropout_30 (Dropout)        (None, 15, 20, 2048)      0
#
#  separable_conv2d_56 (Separa  (None, 11, 16, 14)       79886
#  bleConv2D)
#
#  separable_conv2d_57 (Separa  (None, 9, 14, 14)        336
#  bleConv2D)
#
# ...
# Total params: 23,667,934
# Trainable params: 80,222
# Non-trainable params: 23,587,712
# _________________________________________________________________

# %%
model = get_model()
model.compile(loss="mse", optimizer=keras.optimizers.Adam(1e-4))
model.fit(train_dataset, validation_data=validation_dataset, epochs=EPOCHS)
# Out:
# Epoch 1/10
# 13/20 [==================>...........] - ETA: 56s - loss: 1.7557e-05
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [450], in <cell line: 3>()
#       1 model = get_model()
#       2 model.compile(loss="mse", optimizer=keras.optimizers.Adam(1e-4))
# ----> 3 model.fit(train_dataset, validation_data=validation_dataset, epochs=EPOCHS)
#
# File ~/.local/lib/python3.8/site-packages/keras/utils/traceback_utils.py:64, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      62 filtered_tb = None
#      63 try:
# ---> 64   return fn(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ...

# %%
sample_val_images, sample_val_keypoints = next(iter(validation_dataset))
sample_val_images = sample_val_images[:4]
sample_val_keypoints = sample_val_keypoints[:4].reshape(-1, 7, 2) * IMG_WIDTH * IMG_HEIGHT
predictions = model.predict(sample_val_images).reshape(-1, 7, 2) * IMG_WIDTH * IMG_HEIGHT

# Ground-truth
visualize_keypoints(sample_val_images, sample_val_keypoints)

# Predictions
visualize_keypoints(sample_val_images, predictions)

# %%
import json

with open('result_kp_1.json', 'r') as input_file:
    input_data = json.load(input_file)

print(type(input_data))
print(input_data)
# Out:
# <class 'list'>
# ...

# %%
# for elem in input_data:
#     print(elem["keypoints"])
#     del elem["keypoints"][0]
#     print(elem["keypoints"])
#     del elem["keypoints"][2]
#     print(elem["keypoints"])
#     del elem["keypoints"][3]
#     print(elem["keypoints"])
#     del elem["keypoints"][4]
#     del elem["keypoints"][5]
#     del elem["keypoints"][6]

    
# print(input_data)
#     lst = elem["keypoints"]
#     print(lst)
#     for i in range(len(elem["keypoints"])):
#         if i != 1:
# #             print(elem["keypoints"][i])
#             elem["keypoints"].pop(i)
# # #             elem["keypoints"].remove(elem["keypoints"][i])
# #     print(elem["keypoints"])
#             input_data.remove(elem["keypoints"])
# Out:
# [[198, 462], [194, 328], [293, 243], [317, 261], [447, 361], [477, 340], [505, 384]]
# [[194, 328], [293, 243], [317, 261], [447, 361], [477, 340], [505, 384]]
# [[194, 328], [293, 243], [447, 361], [477, 340], [505, 384]]
# [[194, 328], [293, 243], [447, 361], [505, 384]]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [435], in <cell line: 1>()
#       7 del elem["keypoints"][3]
#       8 print(elem["keypoints"])
# ----> 9 del elem["keypoints"][4]
#      10 del elem["keypoints"][5]
#      11 del elem["keypoints"][6]
#
# IndexError: list assignment index out of range

# %%
print(input_data)
# Out:
# [{'id': 61, 'image': '61.jpg', 'keypoints': [[198, 462], [194, 328], [293, 243], [317, 261], [447, 361], [477, 340], [505, 384]]}, {'id': 1168, 'image': '1168.jpg', 'keypoints': [[200, 462], [191, 323], [56, 317], [65, 285], [195, 194], [188, 157], [229, 146]]}, {'id': 1308, 'image': '1308.jpg', 'keypoints': [[198, 462], [192, 324], [56, 317], [65, 286], [204, 213], [204, 176], [247, 172]]}, {'id': 792, 'image': '792.jpg', 'keypoints': [[198, 462], [197, 322], [105, 224], [133, 201], [293, 236], [312, 204], [352, 229]]}, {'id': 1301, 'image': '1301.jpg', 'keypoints': [[198, 462], [192, 324], [56, 317], [66, 286], [204, 211], [203, 176], [247, 172]]}, {'id': 1039, 'image': '1039.jpg', 'keypoints': [[199.0, 463.0], [194.0, 324.0], [63.0, 286.0], [76.0, 258.0], [226.0, 201.0], [228.0, 161.0], [272.0, 161.0]]}, {'id': 24, 'image': '24.jpg', 'keypoints': [[198, 462], [194, 328], [293, 241], [315, 261], [447, 361], [477, 340], [503, 384]]}, {'id': 2, 'image': '2.jpg', 'keypoints': [[198, 4
# ...
